# %%
y = []

i = 0
c=0
for  i in range(5):    
    a = int(input("5개의 정수값을 입력하시오: "))
    y.append(a)


c = int(len(y))

print(y)
print(f'mean = {sum(y)/c}, sum = {sum(y)}, min = {min(y)}, max = {max(y)}')

# %%
fruits = []

for i in range(5):
    fruit = input("enter a fruit: ")
    fruits.append(fruit)

print(fruits)
print(fruits[-1])
print(fruits[3])

# %%
print("hello")
# Out:
# hello

# %%
# list

numbers = [5,2,8,1]
result1 = sorted(numbers)
result2 = sorted(numbers, reverse=True)
print(result1)
print(result2)
print(numbers)
# Out:
# [1, 2, 5, 8]
# [8, 5, 2, 1]
# [5, 2, 8, 1]

# %%
# tuple

t1 = ()
t2 = (1,)                       # tup1 에 1을 할당하는 명령 튜플맞음
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ('a', 'b', ('ab', 'cd'))  #

# %%
s2 = set("hello")
s2
# Out:
# {'e', 'h', 'l', 'o'}

# %%
dict1 = {1 :"apple", ba: "banana"}

print(dict[1])
print(dict1["ba"])

# %%
id = {"name" : "honggildong", "age": 20, "dept" : "Electric"}

print(id["name"])
print(id["dept"])
id["age"]
# Out:
# honggildong
# Electric
# 20

# %% [markdown]
# #안녕
# ##안녕

# %%
a = {1: "a"}
a[2] = 'b'
a[(1,2)] ='c' 
print(a)
# Out:
# {1: 'a', 2: 'b', (1, 2): 'c'}

# %%
import keyword

print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
a = 3
b = 5
a &= b

# %% [markdown]
# control statement 제어문
# 먼저 기술한 명령이 먼저 실행된다
# 실행의 순서를 제어
#
# 선택문 : if, match~case
# 반복문 : for, while (do~while없음)
# 무시문 : break, continue
# 복귀문 : return

# %%
# 3-1 if문

money = int(input("돈얼마있노:"))

if money >= 20000:
    print("돈많노 texi")
else:
    print("ㅠㅠ walk")

print("Good night")
# Out:
# ㅠㅠ walk
# Good night

# %%
ent = 10000
age = int(input("나이:"))

if age>= 20:
    print("성인")
    입장료 = ent + 0.1 * ent
    if ent >= 입장료:
        print("택시")
    else:
        print("걸어가")
else:
    print("미성년자")
    if ent >= 입장료 :
        print("택시")
    else:
        print("걸어가")
# Out:
# 성인
# 걸어가

# %%
scroe = int(input("점수:"))
if scroe >= 90:
    print("A")
elif scroe >= 80:
    print("B")
elif scroe >= 70:
    print("C")
elif scroe >= 60:
    print("D")
else:
    print("F")
# Out:
# A

# %%
year = int(input("연도:"))
if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    print(f"{year}년은 윤년입니다.")
else:
    print(f"{year}년은 평년입니다.")
# Out:
# 4351454561354652465786765424년은 윤년입니다.
