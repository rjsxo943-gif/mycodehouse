# %%
import matplotlib.pyplot as plt
from sklearn import linear_model

reg = linear_model.LinearRegression()
X = [[174], [175], [138], [128], [186]]
y = [71, 55, 46, 38, 83]

reg.fit(X, y)

reg.predict([[178]])
plt.scatter(X, y, color='blue')
plt.plot(X, reg.predict(X), color='red', linewidth=4)
plt.show()

# %%
from sklearn.datasets import load_iris # 사이킷런에서 붓꽃 데이터셋 로드
iris = load_iris()
df = pd.DataFrame(iris.data)
s=svm.SVC(gamma=0.1, C=10)
s.fit(iris.data, iris.target)
new_d=[[6.4,3.2,6.0,2.5],[]]
res=s.predict(new_d)
print(iris.keys())
print(iris.data[:5]) # 데이터 확인
print(iris.target[:5]) # 레이블 확인
print(iris.target_names) # 레이블 이름 확인
print(iris.feature_names) # 특성 이름 확인
print(iris.DESCR) # 데이터셋 설명 확인
